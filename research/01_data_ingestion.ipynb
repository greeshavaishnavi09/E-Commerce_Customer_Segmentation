# %%
#import current working directory

import os
import sys

print(os.getcwd())
# Out:
# c:\Users\Greesha Vaishnavi\Desktop\dsprojects\E_Commerce_Customer_Segmentation\research

# %%
# Read the sys path
sys.path.append(r"C:\Users\Greesha Vaishnavi\Desktop\dsprojects\E_Commerce_Customer_Segmentation\src")
sys.path.append(r"C:\Users\Greesha Vaishnavi\Desktop\dsprojects\E_Commerce_Customer_Segmentation")

# %%
# present working directory

# %pwd
# Out:
# 'c:\\Users\\Greesha Vaishnavi\\Desktop\\dsprojects\\E_Commerce_Customer_Segmentation\\research'

# %%
# move to parent directory

os.chdir("../")

# %%
# present working directory

# %pwd
# Out:
# 'c:\\Users\\Greesha Vaishnavi\\Desktop\\dsprojects\\E_Commerce_Customer_Segmentation'

# %%
# test project import

import box

print(box.__version__)
# Out:
# 7.4.1

# %%
# entity

from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_data_file: Path
    local_data_file: Path

# %%
from E_Commerce_Customer_Segmentation.constant import *
from E_Commerce_Customer_Segmentation.utils.common import read_yaml,create_directories
from E_Commerce_Customer_Segmentation.entity.config_entity import DataIngestionConfig

# %%
# configuration Manager

class ConfigurationManager:

    def __init__(
        self,
        config_filepath=CONFIG_FILE_PATH,
        params_filepath=PARAMS_FILE_PATH
    ):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_ingestion_config(self) -> DataIngestionConfig:

        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=config.root_dir,
            source_data_file=config.source_data_file,
            local_data_file=config.local_data_file
        )

        return data_ingestion_config

# %%
# import libraries for component

import os
import shutil

from pathlib import Path

from E_Commerce_Customer_Segmentation.logging import logger
from E_Commerce_Customer_Segmentation.utils.common import get_size

# %%
# component

class DataIngestion:

    def __init__(self, config: DataIngestionConfig):
        self.config = config

    def copy_data_file(self):

        if not os.path.exists(self.config.local_data_file):

            shutil.copy(
                self.config.source_data_file,
                self.config.local_data_file
            )

            logger.info("Dataset copied successfully")

        else:

            logger.info("Dataset already exists")

# %%
# pipeline
class DataIngestionTrainingPipeline:

    def __init__(self):
        pass

    def main(self):

        try:

            print("--- STARTING DATA INGESTION PIPELINE ---")

            config = ConfigurationManager()

            data_ingestion_config = config.get_data_ingestion_config()

            data_ingestion = DataIngestion(config=data_ingestion_config)

            data_ingestion.copy_data_file()

            print("--- DATA INGESTION COMPLETED SUCCESSFULLY ---")

        except Exception as e:
            raise e

# %%
obj = DataIngestionTrainingPipeline()
obj.main()
# Out:
# --- STARTING DATA INGESTION PIPELINE ---
# [2026-08-22 00:13:23,793: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-08-22 00:13:23,797: INFO: common: yaml file: params.yaml loaded successfully]
# ---------------------------------------------------------------------------
# BoxValueError                             Traceback (most recent call last)
# File ~\Desktop\dsprojects\E_Commerce_Customer_Segmentation\src\E_Commerce_Customer_Segmentation\utils\common.py:24, in read_yaml(path_to_yaml)
#      22         logger.info(f"yaml file: {path_to_yaml} loaded successfully")
# ---> 24         return ConfigBox(content)
#      26 except BoxValueError:
#
# File c:\Users\Greesha Vaishnavi\.conda\envs\clust\lib\site-packages\box\box.py:301, in box.box.Box.__init__()
#
# BoxValueError: First argument must be mapping or iterable
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 obj = DataIngestionTrainingPipeline()
# ----> 2 obj.main()
#
# Cell In[12], line 24, in DataIngestionTrainingPipeline.main(self)
#      21     print("--- DATA INGESTION COMPLETED SUCCESSFULLY ---")
#      23 except Exception as e:
# ---> 24     raise e
#
# Cell In[12], line 13, in DataIngestionTrainingPipeline.main(self)
#       9 try:
#      11     print("--- STARTING DATA INGESTION PIPELINE ---")
# ---> 13     config = ConfigurationManager()
#      15     data_ingestion_config = config.get_data_ingestion_config()
#      17     data_ingestion = DataIngestion(config=data_ingestion_config)
#
# Cell In[9], line 12, in ConfigurationManager.__init__(self, config_filepath, params_filepath)
#       5 def __init__(
#       6     self,
#       7     config_filepath=CONFIG_FILE_PATH,
#       8     params_filepath=PARAMS_FILE_PATH
#       9 ):
#      11     self.config = read_yaml(config_filepath)
# ---> 12     self.params = read_yaml(params_filepath)
#      14     create_directories([self.config.artifacts_root])
#
# File c:\Users\Greesha Vaishnavi\.conda\envs\clust\lib\site-packages\ensure\main.py:872, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
#     870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
# --> 872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#     874     msg = "Return value of {f} of type {valt} " "does not match annotation type {t}"
#
# File ~\Desktop\dsprojects\E_Commerce_Customer_Segmentation\src\E_Commerce_Customer_Segmentation\utils\common.py:27, in read_yaml(path_to_yaml)
#      24         return ConfigBox(content)
#      26 except BoxValueError:
# ---> 27     raise ValueError("YAML file is empty")
#      29 except Exception as e:
#      30     raise e
#
# ValueError: YAML file is empty
